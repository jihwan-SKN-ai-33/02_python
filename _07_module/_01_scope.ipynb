# %% [markdown]
# # 유효범위 Scope
#
# 변수의 유효범위(scope)는 변수에 접근할 수 있는 범위를 의미한다.
#
# - 전역 변수(global variable): 함수 블록 밖에서 선언되어 여러 위치에서 접근할 수 있는 변수
# - 지역 변수(local variable): 함수 내부에서 선언되어 해당 함수 안에서 주로 사용하는 변수
# - Python의 `for`, `if` 블록은 Java의 중괄호 블록처럼 별도의 지역 스코프를 만들지 않는다.

# %% [markdown]
# ## 1. 전역 변수와 지역 변수
#
# 함수 밖에서 선언된 `a`는 전역 변수이고, 함수 안에서 선언된 `b`는 지역 변수이다.
# `b`는 `foo()` 함수 내부에서만 사용할 수 있다.

# %%
a = 100 # 전역변수 Global
def foo():
    print("foo 에서 출력한 a : ", a)
    b = 20 # 지역번수 : local
    print("foo 에서 출력한 b : ", b)

foo()
print("함수 밖에서 출력한 a : " , a)
# print("함수 밖에서 출력한 b : " , b)

# %% [markdown]
# ## 2. for, if 블록과 스코프
#
# Python에서는 `for`, `if` 블록이 별도의 지역 스코프를 만들지 않는다.
# 따라서 블록 안에서 만들어진 이름을 블록 밖에서도 참조할 수 있다.

# %%
# 왜 이따구지?
# for와 if문에서 선언된 변수는 global로 취급, 지역변수를 가질 수 없다
for i in range(3):
    print(f'for문 내 i : {i}')
    j = 100

print("for문 종료 후 i : " , i)
print("for문 종료 후 j : " , j)

if j == 100:
    k = 200
print("if문 종료 후 k : " , k)
# Out:
# for문 내 i : 0
# for문 내 i : 1
# for문 내 i : 2
# for문 종료 후 i :  2
# for문 종료 후 j :  100
# if문 종료 후 k :  200

# %% [markdown]
# ## 3. 이름 탐색 우선순위
#
# 같은 이름의 변수가 여러 범위에 있을 때는 더 가까운 범위의 변수가 우선된다.
# 함수 안에서 같은 이름으로 대입하면 전역 변수를 바꾸는 것이 아니라, 지역 변수를 새로 만든다.

# %%
x = 100
def bar():
    x = 200
    print("bar 에서 호출한 x : " , x)

bar()
print("밖에서 출력한 x : " , x)
# Out:
# bar 에서 호출한 x :  200
# 밖에서 출력한 x :  100

# %% [markdown]
# ## 4. 전역 변수와 지역 변수가 함께 사용되는 경우
#
# 아래 예제에서 `koo()` 함수 안의 `glo`는 지역 변수이고, 함수 밖의 `glo`와는 다른 이름 공간에 있다.

# %%
glo = 10
bal = 5

def koo(a:int) -> int:
    glo = a + 20
    print("koo() 함수 내 glo 출력 : ", glo)

    b = a + glo + bal
    print(f"b : {b} = a:{a} , glo : {glo} , bal : {bal}")
    return b

koo(7)
print("koo() 함수 밖 glo 출력 : ", glo)
print("koo(7) 반환값 : ", koo(7))
# Out:
# koo() 함수 내 glo 출력 :  27
# b : 39 = a:7 , glo : 27 , bal : 5
# koo() 함수 밖 glo 출력 :  10
# koo() 함수 내 glo 출력 :  27
# b : 39 = a:7 , glo : 27 , bal : 5
# koo(7) 반환값 :  39

# %% [markdown]
# ## 5. immutable, mutable 객체 전달
#
# Python은 함수에 값을 전달할 때 객체에 대한 참조를 전달한다.
# 다만 immutable 객체는 내부 값을 직접 바꿀 수 없고, mutable 객체는 내부 값을 바꿀 수 있어 결과가 다르게 보인다.
#
# - immutable: `int`, `float`, `bool`, `tuple`, `str`
# - mutable: `list`, `dict`, `set`

# %%
def func1(a:int):
    a = 200 # 전달받은 a에 새값을 입력된것이 아닌 새로운 지역변수가 생성된것
    print(f"func1() 내부 a : {a},  id : {id(a)}" )
a = 100
print(f"func1() 호출 전 a : {a},  id : {id(a)}" )
func1(a)
print(f"func1() 호출 후 a : {a},  id : {id(a)}")
# Out:
# func1() 호출 전 a : 100,  id : 4480118792
# func1() 내부 a : 200,  id : 4480121992
# func1() 호출 후 a : 100,  id : 4480118792

# %%
def func2(b: list) -> None:
    b[0] = 999

b =[1,2,3]
print(f"func2() 호출 전 b : {b},  id : {id(b)}")
func2(b)
print(f"func2() 호출 후 b : {b},  id : {id(b)}")
# Out:
# func2() 호출 전 b : [1, 2, 3],  id : 4524014912
# func2() 호출 후 b : [999, 2, 3],  id : 4524014912
